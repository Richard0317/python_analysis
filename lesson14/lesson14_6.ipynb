# %% [markdown]
# # 條狀圖

# %%
import matplotlib.pyplot as plt
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']

plt.bar(subject, values)
# Out:
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']

plt.bar(subject, values)

print(plt.xticks())
# Out:
# ([0, 1, 2, 3, 4], [Text(0, 0, 'apple'), Text(1, 0, 'banana'), Text(2, 0, 'orange'), Text(3, 0, 'tomato'), Text(4, 0, 'guava')])

# %%
print(plt.xticks())
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), [Text(0.0, 0, '0.0'), Text(0.2, 0, '0.2'), Text(0.4, 0, '0.4'), Text(0.6000000000000001, 0, '0.6'), Text(0.8, 0, '0.8'), Text(1.0, 0, '1.0')])

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values)

print(plt.xticks())
# Out:
# (array([2., 3., 4., 5., 6., 7., 8.]), [Text(2.0, 0, '2'), Text(3.0, 0, '3'), Text(4.0, 0, '4'), Text(5.0, 0, '5'), Text(6.0, 0, '6'), Text(7.0, 0, '7'), Text(8.0, 0, '8')])

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values)
plt.xticks(index, subject)
print(plt.xticks())
# Out:
# (array([3, 4, 5, 6, 7]), [Text(3, 0, 'apple'), Text(4, 0, 'banana'), Text(5, 0, 'orange'), Text(6, 0, 'tomato'), Text(7, 0, 'guava')])

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values)
plt.xticks(index, subject)
print(plt.xticks())
for idx,i in enumerate(index):
    plt.annotate(str(values[idx]),(i,values[idx]))
# Out:
# (array([3, 4, 5, 6, 7]), [Text(3, 0, 'apple'), Text(4, 0, 'banana'), Text(5, 0, 'orange'), Text(6, 0, 'tomato'), Text(7, 0, 'guava')])

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values)
plt.xticks(index, subject)
print(plt.xticks())
for idx,i in enumerate(index):
    plt.annotate(str(values[idx]),(i-0.2,values[idx]+100))
# Out:
# (array([3, 4, 5, 6, 7]), [Text(3, 0, 'apple'), Text(4, 0, 'banana'), Text(5, 0, 'orange'), Text(6, 0, 'tomato'), Text(7, 0, 'guava')])

# %%
for idx,i in enumerate(index):
    print(i)
    print(idx)
    print("====")
# Out:
# 3
# 0
# ====
# 4
# 1
# ====
# 5
# 2
# ====
# 6
# 3
# ====
# 7
# 4
# ====

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values)
plt.xticks(index, subject)
print(plt.xticks())
for idx,i in enumerate(index):
    plt.annotate(str(values[idx]),(i-0.2,values[idx]+100))

plt.axis()
# Out:
# (array([3, 4, 5, 6, 7]), [Text(3, 0, 'apple'), Text(4, 0, 'banana'), Text(5, 0, 'orange'), Text(6, 0, 'tomato'), Text(7, 0, 'guava')])
# (np.float64(2.3600000000000003),
#  np.float64(7.64),
#  np.float64(0.0),
#  np.float64(9450.0))

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values)
plt.xticks(index, subject)
print(plt.xticks())
for idx,i in enumerate(index):
    plt.annotate(str(values[idx]),(i-0.2,values[idx]+100))

xmin, xmax, ymin, ymax = plt.axis()
xmin -= 0.2
xmax += 0.2
ymin = 3000
ymax += 1000
plt.axis(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
# Out:
# (array([3, 4, 5, 6, 7]), [Text(3, 0, 'apple'), Text(4, 0, 'banana'), Text(5, 0, 'orange'), Text(6, 0, 'tomato'), Text(7, 0, 'guava')])
# (np.float64(2.16), np.float64(7.84), np.float64(3000.0), np.float64(10450.0))

# %%
import matplotlib.pyplot as plt
import numpy as np
index = np.array([3, 4, 5, 6, 7])
values1 = [5000, 6000, 7000, 8000, 9000]
values2 = [3000, 4000, 5000, 6000, 7000]
values3 = [4000, 5000, 6000, 7000, 8000]

subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values1,color='r',width=0.3)
plt.bar(index+0.3, values2,color='b',width=0.3)
plt.bar(index-0.3, values3,color='g',width=0.3)
plt.xticks(index, subject)


xmin, xmax, ymin, ymax = plt.axis()
xmin -= 0.2
xmax += 0.2
ymin = 1000
ymax += 1000
_ = plt.axis(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)

# %% [markdown]
# # pie

# %%
import matplotlib.pyplot as plt
values = [20, 30, 45, 10]
labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
colors = ['yellow', 'green', 'red', 'blue']

plt.pie(values,labels=labels,colors=colors,startangle=180,explode=[0.3, 0, 0, 0],shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x274dae51300>,
#   <matplotlib.patches.Wedge at 0x274dae51240>,
#   <matplotlib.patches.Wedge at 0x274dae52290>,
#   <matplotlib.patches.Wedge at 0x274dae52c20>],
#  [Text(-1.156734148241646, -0.7886482804721467, 'Nokia'),
#   Text(0.5499999116781021, -0.9526279951555487, 'Samsung'),
#   Text(0.40187477416240713, 1.0239612619098022, 'Apple'),
#   Text(-1.0511301576574053, 0.3242304607268084, 'Lumia')],
#  [Text(-0.7436148095839152, -0.5069881803035228, '19.0%'),
#   Text(0.2999999518244193, -0.5196152700848446, '28.6%'),
#   Text(0.21920442227040388, 0.5585243246780739, '42.9%'),
#   Text(-0.5733437223585847, 0.1768529785782591, '9.5%')])
