# %%
#標準寫法
import matplotlib.pyplot as plt

# 1.製作figure
fig = plt.figure()

# 2.在1.的figure上製作一個axes
ax_1 = fig.add_subplot(1, 1, 1)

# 3.將圖的數據儲存在axes中
X = [0, 1, 2]
Y = [3, 4, 5]
ax_1.plot(X, Y)

# 4.顯示圖
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
X = [0, 1, 2]
Y = [3, 4, 5]
axes.plot(X,Y)
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
X = [0, 3, 9]
Y = [3, 4, 5]
axes.plot(X,Y,color='green',marker='o',linestyle='dashed',linewidth=2,markersize=12)
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
X = [0, 3, 9]
Y = [3, 4, 5]
axes.plot(X,Y,'go--', linewidth=2, markersize=12)
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(1, 3, 1)
axes2 = figure.add_subplot(1, 3, 2)
axes3 = figure.add_subplot(1, 3, 3)

axes1.set_title("plot1")
axes2.set_title("plot2")
axes3.set_title("plot3")
plt.show()

# %%
# !pip install wget
# Out:
# Collecting wget
#   Using cached wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9712 sha256=b7cab8e8efa34667d588baf63533f11082af2b018725a6d4d4c8ea92fd63d890
#   Stored in directory: c:\users\dpr03\appdata\local\pip\cache\wheels\8b\f1\7f\5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
#   DEPRECATION: Building 'wget' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'wget'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %% [markdown]
# # 下載中文字型(此字體較漂亮)

# %%
import wget

wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %% [markdown]
# # 加入中文字型

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

figure = plt.figure()
axes1 = figure.add_subplot(1, 3, 1)
axes2 = figure.add_subplot(1, 3, 2)
axes3 = figure.add_subplot(1, 3, 3)

axes1.set_title("圖表1")
axes2.set_title("圖表2")
axes3.set_title("圖表3")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student1.keys()
# Out:
# dict_keys(['國文', '英文', '數學', '歷史', '探索'])

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font, family="ChineseFont')

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student1.values()
# Out:
# dict_values([78, 80, 92, 75, 85])

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font, family="ChineseFont')

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student1.items()
# Out:
# dict_items([('國文', 78), ('英文', 80), ('數學', 92), ('歷史', 75), ('探索', 85)])

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
subjects = list(student1.keys())
stu1_values = list(student1.values())
subjects, stu1_values
